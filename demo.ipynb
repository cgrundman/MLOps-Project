# %%
import requests
import json

# Set the URL of the server, depending on where it is running
# If running on raspberry pi you may need to replace the adress with the actual IP address

#server_url = 'http://raspberrypi:5000/predict'
server_url = 'http://localhost:5000/predict'

# %%
# Example input data: Modify this according to the input format expected by your model
query = "deutschlandticket"

# Advanced Search Filters
since = "2023-06-06"
until = "2023-06-08"

data = {'query': query, 'until' : until, 'since' : since}

# Send the request to the server
response = requests.post(server_url, json=data)

# Check if the request was successful
if response.status_code == 200:
    response = response.json()

    for tweet in response:
        print(f"User: {tweet['username']}\tDate: {tweet['date']}")
        print(tweet['content'])
        print(f"\nSentiment Score: {tweet['prediction']}")
        print("\n- - - - - - - - - - - - -\n")
else:
    print('Error:', response.status_code)
# Out:
# User: Option_21	Date: Wed, 07 Jun 2023 23:52:28 GMT
# @EinTim2 Danke für Dein Engagement !
# Viel Erfolg mit dem #Kulturpass.
#
# Ein #DeutschlandPass für grenzenlose Mobilität wäre auch ein gutes Arbeitsfeld. Das könnte die nächste Generation für ein besseres Deutschlandticket werden. 👍
#
# Sentiment Score: 0.48368220022964237
#
# - - - - - - - - - - - - -
#
# User: martin_kraft	Date: Wed, 07 Jun 2023 23:18:31 GMT
# @3811015 @fapo85s @DB_Bahn Achso, es geht um das Deutschlandticket?!
#
# Da gibt es ja noch diverse andere Apps von diversen regionalen ÖPNV-Dienstleistern, die das verkaufen und anzeigen.
#
# Mit der ESWE-App z.B. ist das in wenigen Minuten erledigt:
#
# https://t.co/IjHSMvtvsA
#
# Sentiment Score: 0.865335760348986
#
# - - - - - - - - - - - - -
#
# User: 3811015	Date: Wed, 07 Jun 2023 23:08:23 GMT
# @martin_kraft @fapo85s @DB_Bahn Ja, da gibt es das Deutschlandticket aber halt nicht.
#
# Sentiment Score: 0.3567175512260221
#
# - - - - - - - - - - - - -
#
# User: h3adbeat	Date: Wed, 07 Jun 2023 22:53:55 GMT
# @rbb24 Wo ist der ÖPNV in Berlin teuer(er geworden)? Dank Deutschlandticket hat sich der Monatsticketpreis fast halbiert und das bei vielfacher Leistung.
# Von 86€/Monat nur für Berlin auf 49€/Monat für 16 Bundesländer.
#
# Sentiment Score: 0.7339124816909798
#
# - - - - - - - - - - - - -
#
# User: BringASmileToIt	Date: Wed, 07 Jun 2023 22:24:33 GMT
# @Zugzwang74 Hättest du dir nicht ein Monatsticket oder Jahresabo holen können, und dies wäre dann automatisch auf den Preis vom Deutschlandticket gesunken? Trotz aller Vorteile des Verbundtickets?
#
# Hypothetischer Gedanke eines "hier fährt kein Bus auf dem Land"-Kindes.
#
# Sentiment Score: 0.19598265716972174
#
# - - - - - - - - - - - - -
#
# User: teltarif	Date: Wed, 07 Jun 2023 22:20:59 GMT
# Kartellamt gegen Vodafone, Deutschlandticket-Probleme, Apple-Neuheiten https://t.co/n35KL8wx7M
#
# Sentiment Score: 0.9829268956526946
#
# - - - - - - - - - - - - -
#
# User: BerlinReporter	Date: Wed, 07 Jun 2023 21:58:59 GMT
# Vielleicht wäre zum #Deutschlandticket noch die Golden-Bahnhofsklo-Card eine wichtige Ergänzung.
#
# Sentiment Score: 0.4407447191705597
#
# - - - - - - - - - - - - -
#
# User: HasenLady	Date: Wed, 07 Jun 2023 21:33:36 GMT
# @HerrGrafOlaf Deutschlandticket günstiger als Miete😁
#
# Sentiment Score: 0.97621137464378
#
# - - - - - - - - - - - - -
#
# User: WScrapyard	Date: Wed, 07 Jun 2023 21:15:23 GMT
# @n3ll41 Nö also ich möchte für das Deutschlandticket gerne 69€ statt 49€ zahlen.
#
# Sentiment Score: 0.2662000590800393
#
# - - - - - - - - - - - - -
#
# User: Johzinda	Date: Wed, 07 Jun 2023 20:57:44 GMT
# @rbb24 Na da nehme ich doch gleich das Deutschlandticket. https://t.co/Id41JXoyQ2
#
# Sentiment Score: 0.22804279759866442
#
# - - - - - - - - - - - - -
#
# User: _Leoooon_	Date: Wed, 07 Jun 2023 20:52:48 GMT
# Deutschlandticket macht Leben so viel entspannter 😮‍💨
#
# Sentiment Score: 0.14101287594318868
#
# - - - - - - - - - - - - -
